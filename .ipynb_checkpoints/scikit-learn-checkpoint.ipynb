# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\rodrigo\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rodrigo\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\rodrigo\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\rodrigo\anaconda3\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\rodrigo\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)

# %%
# Importando as dependências
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
# Fonte dos dados
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"

# Rótulos que daremos aos atributos (colunas) da nossa tabela de dados
columns = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'variety']

# Criando um DataFrame em Pandas para nosso trabalho
data = pd.read_csv(url, names=columns)

# %%
# Entendendo o cabeçalho do DataFrame
data.head(5)
# Out:
#    sepal-length  sepal-width  petal-length  petal-width      variety
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Visualizando o número de instâncias por classes
data.groupby('variety').size()
# Out:
# variety
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# #### Criando o classificador

# %%
# Criando subconjuntos de treino (train) e teste (test)
train, test = train_test_split(data, test_size = 0.4, stratify = data['variety'], random_state = 42)

# Rotulando os conjuntos de treino e teste
X_train = train[['sepal-length','sepal-width','petal-length','petal-width']]
y_train = train.variety
X_test = test[['sepal-length','sepal-width','petal-length','petal-width']]
y_test = test.variety

# %% [markdown]
# #### Rodando o modelo e medindo a acurácia

# %%
# Rodando o modelo
mod_dt = DecisionTreeClassifier(max_depth = 3, random_state = 1)
mod_dt.fit(X_train,y_train)
prediction=mod_dt.predict(X_test)

# Medindo a acurácia
print("Acurácia do modelo:","{:.3f}".format(metrics.accuracy_score(prediction,y_test)))
# Out:
# Acurácia do modelo: 0.983

# %%
# Visualizando a “árvore” de decisões
variety = ['Setosa', 'Versicolor', 'Virginica']
plt.figure(figsize = (10,8))
plot_tree(mod_dt, feature_names = columns, class_names = variety, filled = True);

# %%
mod_dt.feature_importances_

#Se você rodar mod_dt.feature_importances_ em uma nova célula, verá uma lista Python, que começam com dois zeros. 
#Isso quer dizer que os tamanhos das sépalas não foram considerados nas decisões, apenas o das pétalas foram suficientes.
# Out:
# array([0.        , 0.        , 0.42430866, 0.57569134])
